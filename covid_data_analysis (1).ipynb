# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("covid19_global_statistics_2026.csv")
print(df)
# Out:
#          continent           country   population        date  new_cases  \
# 0           Africa           Eritrea    3662244.0  2026-02-16        NaN
# 1           Africa             Niger   26083660.0  2026-02-16        NaN
# 2           Africa      Saint-Helena       6115.0  2026-02-16        NaN
# 3    South-America  Falkland-Islands       3539.0  2026-02-16        NaN
# 4    North-America        Montserrat       4965.0  2026-02-16        NaN
# ..             ...               ...          ...         ...        ...
# 233         Europe                UK   68497907.0  2026-02-16        NaN
# 234         Europe            Russia  145805947.0  2026-02-16        NaN
# 235           Asia            Turkey   85561976.0  2026-02-16        NaN
# 236        Oceania         Australia   26068792.0  2026-02-16        NaN
# 237           Asia           Vietnam   98953541.0  2026-02-16        NaN
#
#      active_cases  cases_per_million  total_cases  new_deaths  \
# 0             0.0             2782.0        10189         NaN
# 1           729.0              381.0         9931         NaN
# 2          2164.0           354211.0         2166         NaN
# 3             0.0           545352.0         1930         NaN
# 4            19.0           282578.0         1403         NaN
# ..            ...                ...          ...         ...
# 233           0.0           363666.0     24910387         NaN
# 234      175641.0           165454.0     24124215         NaN
# 235           NaN           201399.0     17232066         NaN
# 236        8716.0           454687.0     11853144         NaN
# 237      941018.0           117481.0     11625195         NaN
#
#      deaths_per_million  total_deaths  tests_per_million  total_tests
# 0                  28.0         103.0             6470.0      23693.0
# 1                  12.0         312.0             9759.0     254538.0
# 2                   NaN           NaN                NaN          NaN
# 3                   NaN           NaN          2439107.0       8632.0
# 4                1611.0           8.0          3577442.0      17762.0
# ..                  ...           ...                ...          ...
# 233              3389.0      232112.0          7628357.0  522526476.0
# 234              2762.0      402756.0          1875095.0  273400000.0
# 235              1194.0      102174.0          1902052.0  162743369.0
# 236               937.0       24414.0          3142326.0   81916639.0
# 237               437.0       43206.0           867342.0   85826548.0
#
# [238 rows x 13 columns]

# %%
#Now lets do basic inspection

# %%
df.head() #this will give 1st 5 rows in dataset
# Out:
#        continent           country  population        date  new_cases  \
# 0         Africa           Eritrea   3662244.0  2026-02-16        NaN
# 1         Africa             Niger  26083660.0  2026-02-16        NaN
# 2         Africa      Saint-Helena      6115.0  2026-02-16        NaN
# 3  South-America  Falkland-Islands      3539.0  2026-02-16        NaN
# 4  North-America        Montserrat      4965.0  2026-02-16        NaN
#
#    active_cases  cases_per_million  total_cases  new_deaths  \
# 0           0.0             2782.0        10189         NaN
# 1         729.0              381.0         9931         NaN
# 2        2164.0           354211.0         2166         NaN
# 3           0.0           545352.0         1930         NaN
# 4          19.0           282578.0         1403         NaN
#
#    deaths_per_million  total_deaths  tests_per_million  total_tests
# 0                28.0         103.0             6470.0      23693.0
# 1                12.0         312.0             9759.0     254538.0
# 2                 NaN           NaN                NaN          NaN
# 3                 NaN           NaN          2439107.0       8632.0
# 4              1611.0           8.0          3577442.0      17762.0

# %%
df.head(10) # u can customize the number of rows also
# Out:
#        continent           country    population        date  new_cases  \
# 0         Africa           Eritrea  3.662244e+06  2026-02-16        NaN
# 1         Africa             Niger  2.608366e+07  2026-02-16        NaN
# 2         Africa      Saint-Helena  6.115000e+03  2026-02-16        NaN
# 3  South-America  Falkland-Islands  3.539000e+03  2026-02-16        NaN
# 4  North-America        Montserrat  4.965000e+03  2026-02-16        NaN
# 5            NaN  Diamond-Princess           NaN  2026-02-16        NaN
# 6         Europe      Vatican-City  7.990000e+02  2026-02-16        NaN
# 7         Africa    Western-Sahara  6.261610e+05  2026-02-16        NaN
# 8            NaN        MS-Zaandam           NaN  2026-02-16        NaN
# 9           Asia             China  1.448471e+09  2026-02-16        NaN
#
#    active_cases  cases_per_million  total_cases  new_deaths  \
# 0           0.0             2782.0        10189         NaN
# 1         729.0              381.0         9931         NaN
# 2        2164.0           354211.0         2166         NaN
# 3           0.0           545352.0         1930         NaN
# 4          19.0           282578.0         1403         NaN
# 5           0.0                NaN          712         NaN
# 6           0.0            36295.0           29         NaN
# 7           0.0               16.0           10         NaN
# 8           0.0                NaN            9         NaN
# 9      118977.0              347.0       503302         NaN
#
#    deaths_per_million  total_deaths  tests_per_million  total_tests
# 0                28.0         103.0             6470.0      23693.0
# 1                12.0         312.0             9759.0     254538.0
# 2                 NaN           NaN                NaN          NaN
# 3                 NaN           NaN          2439107.0       8632.0
# 4              1611.0           8.0          3577442.0      17762.0
# 5                 NaN          13.0                NaN          NaN
# 6                 NaN           NaN                NaN          NaN
# 7                 2.0           1.0                NaN          NaN
# 8                 NaN           2.0                NaN          NaN
# 9                 4.0        5272.0           110461.0  160000000.0

# %%
df.tail(7) #it will give the last 7rows of the data set
# Out:
#     continent    country   population        date  new_cases  active_cases  \
# 231      Asia      Japan  125584838.0  2026-02-16        NaN           NaN
# 232    Europe      Italy   60262770.0  2026-02-16        NaN      165544.0
# 233    Europe         UK   68497907.0  2026-02-16        NaN           0.0
# 234    Europe     Russia  145805947.0  2026-02-16        NaN      175641.0
# 235      Asia     Turkey   85561976.0  2026-02-16        NaN           NaN
# 236   Oceania  Australia   26068792.0  2026-02-16        NaN        8716.0
# 237      Asia    Vietnam   98953541.0  2026-02-16        NaN      941018.0
#
#      cases_per_million  total_cases  new_deaths  deaths_per_million  \
# 231           269169.0     33803572         NaN               595.0
# 232           443445.0     26723249         NaN              3261.0
# 233           363666.0     24910387         NaN              3389.0
# 234           165454.0     24124215         NaN              2762.0
# 235           201399.0     17232066         NaN              1194.0
# 236           454687.0     11853144         NaN               937.0
# 237           117481.0     11625195         NaN               437.0
#
#      total_deaths  tests_per_million  total_tests
# 231       74694.0           799578.0  100414883.0
# 232      196487.0          4665010.0  281126449.0
# 233      232112.0          7628357.0  522526476.0
# 234      402756.0          1875095.0  273400000.0
# 235      102174.0          1902052.0  162743369.0
# 236       24414.0          3142326.0   81916639.0
# 237       43206.0           867342.0   85826548.0

# %%
df.info() #it gives all the basic info of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   continent           236 non-null    object
#  1   country             238 non-null    object
#  2   population          229 non-null    float64
#  3   date                238 non-null    object
#  4   new_cases           17 non-null     float64
#  5   active_cases        191 non-null    float64
#  6   cases_per_million   230 non-null    float64
#  7   total_cases         238 non-null    int64
#  8   new_deaths          3 non-null      float64
#  9   deaths_per_million  225 non-null    float64
#  10  total_deaths        233 non-null    float64
#  11  tests_per_million   213 non-null    float64
#  12  total_tests         213 non-null    float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 24.3+ KB

# %%
df.columns #it gives all the column names present in dataset
# Out:
# Index(['continent', 'country', 'population', 'date', 'new_cases',
#        'active_cases', 'cases_per_million', 'total_cases', 'new_deaths',
#        'deaths_per_million', 'total_deaths', 'tests_per_million',
#        'total_tests'],
#       dtype='object')

# %%
df.describe() #it gives statistically information of the dataset
# Out:
#          population   new_cases  active_cases  cases_per_million  \
# count  2.290000e+02   17.000000  1.910000e+02         230.000000
# mean   3.469404e+07  103.058824  2.636781e+05      202460.960870
# std    1.386374e+08  212.516608  1.923405e+06      205838.075508
# min    7.990000e+02    0.000000  0.000000e+00          16.000000
# 25%    4.454310e+05   10.000000  4.550000e+01       19423.250000
# 50%    5.797805e+06   13.000000  6.620000e+02      128762.000000
# 75%    2.210284e+07   63.000000  8.017500e+03      331302.750000
# max    1.448471e+09  702.000000  2.212340e+07      771655.000000
#
#         total_cases  new_deaths  deaths_per_million  total_deaths  \
# count  2.380000e+02    3.000000          225.000000  2.330000e+02
# mean   8.883449e+06    3.333333         1275.668444  9.026621e+04
# std    5.193031e+07    4.163332         1307.746257  5.163434e+05
# min    9.000000e+00    0.000000            2.000000  1.000000e+00
# 25%    2.741875e+04    1.000000          176.000000  2.250000e+02
# 50%    2.320425e+05    2.000000          869.000000  2.570000e+03
# 75%    1.565481e+06    5.000000         2092.000000  1.805700e+04
# max    7.047539e+08    8.000000         6595.000000  7.010681e+06
#
#        tests_per_million   total_tests
# count       2.130000e+02  2.130000e+02
# mean        2.155978e+06  3.298829e+07
# std         3.647972e+06  1.198779e+08
# min         5.093000e+03  7.850000e+03
# 25%         1.981990e+05  3.478150e+05
# 50%         8.851190e+05  2.226216e+06
# 75%         2.439107e+06  1.346373e+07
# max         2.330212e+07  1.186852e+09

# %%
#Now lets start with Data Cleaning

# %%
df.isnull().sum() # this gives number of null values in each column
# Out:
# continent               2
# country                 0
# population              9
# date                    0
# new_cases             221
# active_cases           47
# cases_per_million       8
# total_cases             0
# new_deaths            235
# deaths_per_million     13
# total_deaths            5
# tests_per_million      25
# total_tests            25
# dtype: int64

# %%
#There are 2 options to handle these missing values :
# 1.removing all the missing values and 2.filling all the missing values
df.fillna(0,inplace=True) # this is used to fill all the missing values with 0
# df.dropna(inplace=True) = this is used to remove or delete all the missing values

# %%
df.isnull().sum() #AS all the values are filled there are no null values so the count will be zero
# Out:
# continent             0
# country               0
# population            0
# date                  0
# new_cases             0
# active_cases          0
# cases_per_million     0
# total_cases           0
# new_deaths            0
# deaths_per_million    0
# total_deaths          0
# tests_per_million     0
# total_tests           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True) #this will delete all the repeated rows and cols

# %%
df.dtypes #this gives the column and its datatype
# Out:
# continent              object
# country                object
# population            float64
# date                   object
# new_cases             float64
# active_cases          float64
# cases_per_million     float64
# total_cases             int64
# new_deaths            float64
# deaths_per_million    float64
# total_deaths          float64
# tests_per_million     float64
# total_tests           float64
# dtype: object

# %%
#As above date column is considered as object we will change object into date-time datatype
df['date'] = pd.to_datetime(df['date'])

# %%
df.dtypes
# Out:
# continent                     object
# country                       object
# population                   float64
# date                  datetime64[ns]
# new_cases                    float64
# active_cases                 float64
# cases_per_million            float64
# total_cases                    int64
# new_deaths                   float64
# deaths_per_million           float64
# total_deaths                 float64
# tests_per_million            float64
# total_tests                  float64
# dtype: object

# %%
#Now Lets Start with Exploratory Data Analysis

# %%
df.groupby('country').sum(numeric_only=True).sort_values(by='total_cases', ascending=False).head(1)
#this gives the country with highest cases
#Insight : All named country is having highest cases
# Out:
#          population  new_cases  active_cases  cases_per_million  total_cases  \
# country
# All             0.0        0.0    22123398.0            90413.0    704753890
#
#          new_deaths  deaths_per_million  total_deaths  tests_per_million  \
# country
# All             0.0               899.4     7010681.0                0.0
#
#          total_tests
# country
# All              0.0

# %%
df.groupby('country')['new_deaths'].sum().sort_values(ascending=False).head(1)
#this gives the country with max number of deaths
#insight : Spain is the country with more number of deaths
# Out:
# country
# Spain    8.0
# Name: new_deaths, dtype: float64

# %%
df.groupby('continent')['total_cases'].sum().sort_values(ascending=False)
#this gives all the total cases in each continent
#Insight : The continent names All is having max number of cases
# Out:
# continent
# All              704753890
# Europe           506812396
# Asia             443000530
# North-America    263778264
# South-America    140401758
# Oceania           29791542
# Africa            25721848
# Name: total_cases, dtype: int64

# %%
df.groupby('country')['total_tests'].max().sort_values(ascending=False).head(10)
# this gives the country which done more number of testing
# Insight : USA has made more number of testings
# Out:
# country
# USA        1.186852e+09
# India      9.358795e+08
# UK         5.225265e+08
# Spain      4.710363e+08
# Italy      2.811264e+08
# Russia     2.734000e+08
# France     2.714902e+08
# Austria    2.112735e+08
# UAE        2.007323e+08
# Turkey     1.627434e+08
# Name: total_tests, dtype: float64

# %%
#We will start Visualisations

# %%
top_cases = df.groupby('country')['total_cases'].max().sort_values(ascending=False).head(10)

top_cases.plot(kind='bar')
plt.title("Top 10 Countries by Total Cases")
plt.ylabel("Total Cases")
plt.show()
#It gives the visualisation for top 10 countries by total cases

# %%
continent_cases = df.groupby('continent')['total_cases'].sum()

continent_cases.plot(kind='pie', autopct='%1.1f%%')
plt.title("Continent-wise COVID Cases")
plt.ylabel("")
plt.show()
#It gives a pie chart for continent wise covid cases

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(df['total_cases'], bins=30)
plt.title("Distribution of Total Cases")
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
# Conclusion

# 1. USA performed highest testing
# 2. Spain recorded highest deaths
# 3. Cases are concentrated heavily in few countries
# 4. Testing and total cases show positive relationship
